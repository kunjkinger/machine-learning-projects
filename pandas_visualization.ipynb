# %% [markdown]
# <a href="https://colab.research.google.com/github/kunjkinger/machine-learning-projects/blob/time_series_analysis/pandas_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df1 = pd.read_csv('df1.csv',index_col=0)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('df2.csv')

# %%
df2
# Out:
#           a         b         c         d  e
# 0  0.039762  0.218517  0.103423  0.957904  x
# 1  0.937288  0.041567  0.899125  0.977680  y
# 2  0.780504  0.008948  0.557808  0.797510  x
# 3  0.672717  0.247870  0.264071  0.444358  z
# 4  0.053829  0.520124  0.552264  0.190008  y
# 5  0.286043  0.593465  0.907307  0.637898  x
# 6  0.430436  0.166230  0.469383  0.497701  z
# 7  0.312296  0.502823  0.806609  0.850519  z
# 8  0.187765  0.997075  0.895955  0.530390  x
# 9  0.908162  0.232726  0.414138  0.432007  y

# %%
df1['A'].plot.hist()

# %%
df1['A'].plot.hist(edgecolor='k').autoscale(enable=True,axis='both',tight=True)#tight will scale the plotting

# %%
df1['A'].plot.hist(bins=20,edgecolor='k').autoscale(enable=True,axis='both',tight=True)#tight will scale the plotting

# %%
df1['A'].plot.hist(grid=True)

# %%
df2.plot.bar()

# %%
df2.plot.bar(stacked=True)

# %%
df2.plot.barh(stacked=True)

# %%
df2.plot.barh()

# %%
df2.plot.line(y='a')

# %%
df2.plot.line(y=['a','b','c'])

# %%
df2.plot.area()

# %%
df2.plot.area(stacked=False,alpha=0.4)

# %%
df1.plot.scatter(x='A',y='B',c='D',cmap='coolwarm')

# %%
df1.plot.scatter(x='A',y='B',s=df1['C']*10,c='C',cmap='coolwarm',alpha=0.4)
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/collections.py:885: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
df2.plot.box()

# %%
df2.boxplot()

# %%
df2['a'].plot.kde() # shows the distribution

# %%
df2.plot.kde()

# %%
import numpy as np
df = pd.DataFrame(np.random.randn(1000,2),columns=['A','B'])

# %%
df
# Out:
#             A         B
# 0   -1.379887 -0.143720
# 1    1.473911 -0.112851
# 2    0.298335  1.305544
# 3   -2.257734  0.832655
# 4   -1.171077  1.538603
# ..        ...       ...
# 995 -0.702078  0.603290
# 996  0.128330  0.043044
# 997  1.171292  0.911707
# 998 -0.175931  1.119927
# 999  0.630254 -0.083076
#
# [1000 rows x 2 columns]

# %%
df.plot.scatter(x='A',y='B')

# %%
df.plot.hexbin(x='A',y='B',gridsize=25)

# %%
df2['c'].plot.line(figsize=(20,4),ls='--',c='red',lw=5)

# %%
title = 'plot title'
xlabel = 'x data'
ylabel = 'y data'

# %%
ax = df2['c'].plot.line(figsize=(20,4),ls='--',c='red',lw=5,title=title)
ax.set(xlabel=xlabel,ylabel=ylabel)
# Out:
# [Text(0, 0.5, 'y data'), Text(0.5, 0, 'x data')]

# %%
ax = df2.plot()
ax.legend(loc=0,bbox_to_anchor=(1.0,1.0))

# %%
df3 = pd.read_csv('df3.csv')

# %%
df3.head()
# Out:
#        weekday  produced  defective
# 0     1.Monday        73          7
# 1    2.Tuesday        75         10
# 2  3.Wednesday        86          7
# 3   4.Thursday        64          7
# 4     5.Friday        70          6

# %%
df3.plot.scatter(x='produced',y='defective',c='r',figsize=(10,4),s=30)

# %%
df3['produced'].plot.hist(edgecolor='k').autoscale(axis='x',tight=True)

# %%
df3[['weekday','produced']].boxplot(by='weekday',figsize=(12,5));

# %%
df3['defective'].plot.kde(ls='--',lw=4)

# %%
ax = df3.loc[0:30].plot.area(stacked=False,alpha=0.4)
ax.legend(loc=0,bbox_to_anchor=(1.0,1.0))
